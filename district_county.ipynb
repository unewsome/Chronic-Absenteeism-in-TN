# %%
import tabula
import pandas as pd

# %%
district_county = tabula.read_pdf("C:/Users/unews/nss_data_science/Capstone/2017-18 Salary Ranking - MA Average.pdf")

# %%
district_county
# Out:
#     Rank             District Name      County Unnamed: 3  Salary  Rank.1  \
# 0    NaN  TN School for the Blind-         NaN        NaN     NaN     NaN
# 1    1.0                       NaN    Davidson          $  59,978    51.0
# 2    NaN                       SSS         NaN        NaN     NaN     NaN
# 3    2.0                 Oak Ridge    Anderson          $  59,197    52.0
# 4    3.0              Johnson City  Washington          $  59,130    53.0
# 5    4.0                 Maryville      Blount          $  58,423    54.0
# 6    5.0                     Alcoa      Blount          $  58,367    55.0
# 7    6.0              Murfreesboro  Rutherford          $  56,771    56.0
# 8    7.0                  Bartlett      Shelby          $  56,479    57.0
# 9    8.0              Collierville      Shelby          $  56,479    58.0
# 10   9.0                 Arlington      Shelby          $  55,959    59.0
# 11  10.0                   Bristol    Sullivan          $  55,900    60.0
# ...

# %%
district_county.to_csv("C:/Users/unews/nss_data_science/Capstone/district_county.csv")
